# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\Admin\Desktop\Amith Projects\Python Projects\HR Analytics\Cleaned_HR_Data_Analysis.csv")
df
# Out:
#       Employee ID  StartDate                    Title BusinessUnit  \
# 0            3427  20-Sep-19  Production Technician I         CCDR
# 1            3428  11-Feb-23  Production Technician I           EW
# 2            3429  10-Dec-18       Area Sales Manager           PL
# 3            3430  21-Jun-21       Area Sales Manager         CCDR
# 4            3431  29-Jun-19       Area Sales Manager          TNS
# ...           ...        ...                      ...          ...
# 2840         3421  09-May-22  Production Technician I           PL
# 2841         3423  28-Dec-20  Production Technician I          SVG
# 2842         3424  09-Dec-20  Production Technician I          TNS
# 2843         3425  28-May-19  Production Technician I          WBL
# 2844         3426  27-Apr-22  Production Technician I          BPC
#
#      EmployeeStatus EmployeeType PayZone EmployeeClassificationType  \
# 0            Active     Contract  Zone C                  Temporary
# ...

# %%
df.head()
# Out:
#    Employee ID  StartDate                    Title BusinessUnit  \
# 0         3427  20-Sep-19  Production Technician I         CCDR
# 1         3428  11-Feb-23  Production Technician I           EW
# 2         3429  10-Dec-18       Area Sales Manager           PL
# 3         3430  21-Jun-21       Area Sales Manager         CCDR
# 4         3431  29-Jun-19       Area Sales Manager          TNS
#
#   EmployeeStatus EmployeeType PayZone EmployeeClassificationType  \
# 0         Active     Contract  Zone C                  Temporary
# 1         Active     Contract  Zone A                  Part-Time
# 2         Active    Full-Time  Zone B                  Part-Time
# 3         Active     Contract  Zone A                  Full-Time
# 4         Active     Contract  Zone A                  Temporary
#
#       DepartmentType              Division  ... Engagement Score  \
# 0  Production         Finance & Accounting  ...                1
# ...

# %%
df.tail()
# Out:
#       Employee ID  StartDate                    Title BusinessUnit  \
# 2840         3421  09-May-22  Production Technician I           PL
# 2841         3423  28-Dec-20  Production Technician I          SVG
# 2842         3424  09-Dec-20  Production Technician I          TNS
# 2843         3425  28-May-19  Production Technician I          WBL
# 2844         3426  27-Apr-22  Production Technician I          BPC
#
#      EmployeeStatus EmployeeType PayZone EmployeeClassificationType  \
# 2840         Active    Part-Time  Zone A                  Part-Time
# 2841         Active    Part-Time  Zone A                  Full-Time
# 2842     Terminated     Contract  Zone B                  Temporary
# 2843     Terminated     Contract  Zone B                  Full-Time
# 2844         Active    Full-Time  Zone B                  Temporary
#
#          DepartmentType               Division  ... Engagement Score  \
# 2840  Production                      Wireless  ...                5
# ...

# %%
df.describe(include="O")
# Out:
#         StartDate                    Title BusinessUnit EmployeeStatus  \
# count        2845                     2845         2845           2845
# unique       1472                       32           10              2
# top     04-Mar-22  Production Technician I          NEL         Active
# freq            7                     1241          291           2458
#
#        EmployeeType PayZone EmployeeClassificationType     DepartmentType  \
# count          2845    2845                       2845               2845
# unique            3       3                          3                  6
# top       Full-Time  Zone A                  Temporary  Production
# freq            997    1013                        980               1910
#
#                 Division         DOB State GenderCode RaceDesc MaritalDesc  \
# count               2845        2845  2845       2845     2845        2845
# unique                25        2664    28          2        5           4
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2845 entries, 0 to 2844
# Data columns (total 28 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee ID                 2845 non-null   int64
#  1   StartDate                   2845 non-null   object
#  2   Title                       2845 non-null   object
#  3   BusinessUnit                2845 non-null   object
#  4   EmployeeStatus              2845 non-null   object
#  5   EmployeeType                2845 non-null   object
#  6   PayZone                     2845 non-null   object
#  7   EmployeeClassificationType  2845 non-null   object
#  8   DepartmentType              2845 non-null   object
#  9   Division                    2845 non-null   object
#  10  DOB                         2845 non-null   object
#  11  State                       2845 non-null   object
#  12  GenderCode                  2845 non-null   object
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Employee ID                   0
# StartDate                     0
# Title                         0
# BusinessUnit                  0
# EmployeeStatus                0
# EmployeeType                  0
# PayZone                       0
# EmployeeClassificationType    0
# DepartmentType                0
# Division                      0
# DOB                           0
# State                         0
# GenderCode                    0
# RaceDesc                      0
# MaritalDesc                   0
# Performance Score             0
# Current Employee Rating       0
# Survey Date                   0
# Engagement Score              0
# Satisfaction Score            0
# Work-Life Balance Score       0
# Training Date                 0
# Training Program Name         0
# Training Type                 0
# Training Outcome              0
# Training Duration(Days)       0
# Training Cost                 0
# Age                           0
# dtype: int64

# %%
df.shape
# Out:
# (2845, 28)

# %%
df.columns
# Out:
# Index(['Employee ID', 'StartDate', 'Title', 'BusinessUnit', 'EmployeeStatus',
#        'EmployeeType', 'PayZone', 'EmployeeClassificationType',
#        'DepartmentType', 'Division', 'DOB', 'State', 'GenderCode', 'RaceDesc',
#        'MaritalDesc', 'Performance Score', 'Current Employee Rating',
#        'Survey Date', 'Engagement Score', 'Satisfaction Score',
#        'Work-Life Balance Score', 'Training Date', 'Training Program Name',
#        'Training Type', 'Training Outcome', 'Training Duration(Days)',
#        'Training Cost', 'Age'],
#       dtype='object')

# %%
df
# Out:
#       Employee ID  StartDate                    Title BusinessUnit  \
# 0            3427  20-Sep-19  Production Technician I         CCDR
# 1            3428  11-Feb-23  Production Technician I           EW
# 2            3429  10-Dec-18       Area Sales Manager           PL
# 3            3430  21-Jun-21       Area Sales Manager         CCDR
# 4            3431  29-Jun-19       Area Sales Manager          TNS
# ...           ...        ...                      ...          ...
# 2840         3421  09-May-22  Production Technician I           PL
# 2841         3423  28-Dec-20  Production Technician I          SVG
# 2842         3424  09-Dec-20  Production Technician I          TNS
# 2843         3425  28-May-19  Production Technician I          WBL
# 2844         3426  27-Apr-22  Production Technician I          BPC
#
#      EmployeeStatus EmployeeType PayZone EmployeeClassificationType  \
# 0            Active     Contract  Zone C                  Temporary
# ...

# %%
df["Satisfaction Score"].agg(["min","max","mean"])
# Out:
# min     1.000000
# max     5.000000
# mean    3.028471
# Name: Satisfaction Score, dtype: float64

# %%
df["Division"].unique()
# Out:
# array(['Finance & Accounting', 'Aerial', 'General - Sga', 'General - Con',
#        'Field Operations', 'General - Eng', 'Engineers', 'Executive',
#        'Splicing', 'Project Management - Con', 'Fielders',
#        'Project Management - Eng', 'Shop (Fleet)',
#        'Wireline Construction', 'Catv', 'Wireless', 'People Services',
#        'Yard (Material Handling)', 'Billable Consultants',
#        'Technology / It', 'Underground', 'Sales & Marketing', 'Isp',
#        'Safety', 'Corp Operations'], dtype=object)

# %%
df["Division"].value_counts()
# Out:
# Division
# Field Operations            747
# General - Con               474
# Engineers                   261
# Aerial                      181
# Wireline Construction       175
# Project Management - Con    172
# General - Sga               112
# Splicing                    108
# General - Eng                85
# Fielders                     80
# Finance & Accounting         69
# Yard (Material Handling)     55
# Catv                         54
# Shop (Fleet)                 53
# Executive                    41
# Wireless                     32
# Underground                  31
# People Services              24
# Billable Consultants         23
# Technology / It              21
# Project Management - Eng     15
# Isp                          14
# Sales & Marketing             8
# Safety                        8
# Corp Operations               2
# Name: count, dtype: int64

# %%
df["Division"].dtype
# Out:
# dtype('O')

# %%
df["Training Outcome"].unique()
# Out:
# array(['Failed', 'Incomplete', 'Completed', 'Passed'], dtype=object)

# %%
df["Training Outcome"].value_counts()
# Out:
# Training Outcome
# Completed     737
# Incomplete    731
# Passed        709
# Failed        668
# Name: count, dtype: int64

# %%
df["Engagement Score"].agg(["max","min","mean"])
# Out:
# max     5.000000
# min     1.000000
# mean    2.941652
# Name: Engagement Score, dtype: float64

# %%
df["StartDate"].value_counts()
# Out:
# StartDate
# 04-Mar-22    7
# 11-Nov-19    7
# 14-Nov-20    6
# 09-Jan-20    6
# 26-Feb-22    6
#             ..
# 11-Jun-20    1
# 28-Feb-23    1
# 18-Dec-21    1
# 01-May-21    1
# 28-May-19    1
# Name: count, Length: 1472, dtype: int64

# %%
df["Training Outcome"].hist()
# Out:
# <Axes: >

# %%
df.plot.scatter(x='Training Outcome',y='Satisfaction Score')
# Out:
# <Axes: xlabel='Training Outcome', ylabel='Satisfaction Score'>

# %%
df['Training Outcome'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Training Outcome'>

# %%
df['Satisfaction Score'].plot(kind='line')
# Out:
# <Axes: >

# %%
df
# Out:
#       Employee ID  StartDate                    Title BusinessUnit  \
# 0            3427  20-Sep-19  Production Technician I         CCDR
# 1            3428  11-Feb-23  Production Technician I           EW
# 2            3429  10-Dec-18       Area Sales Manager           PL
# 3            3430  21-Jun-21       Area Sales Manager         CCDR
# 4            3431  29-Jun-19       Area Sales Manager          TNS
# ...           ...        ...                      ...          ...
# 2840         3421  09-May-22  Production Technician I           PL
# 2841         3423  28-Dec-20  Production Technician I          SVG
# 2842         3424  09-Dec-20  Production Technician I          TNS
# 2843         3425  28-May-19  Production Technician I          WBL
# 2844         3426  27-Apr-22  Production Technician I          BPC
#
#      EmployeeStatus EmployeeType PayZone EmployeeClassificationType  \
# 0            Active     Contract  Zone C                  Temporary
# ...

# %%
# Creating a function that plot the barchart as wells as a pie chart for the categorical column.
def plot_bar_pie(column, dataframe= df, top_n=5):
    """
    Plot barchart and piechart side by side.
    """
    # Check to ensure the column is categorical.
    if dataframe[column].dtypes == "O":
        dist = dataframe[column].value_counts(normalize=True).head(top_n)
        # Start the plotting the barchart.
        fig, (ax0, ax1) = plt.subplots(1, 2, figsize=(15, 5))
        ax0.bar(dist.index, dist.values)
        ax0.set_xticks(range(len(dist.index)))
        ax0.set_xticklabels(rotation=45, labels=dist.index)
        ax0.set_title(f"Bar chart Distribution for {column}")
        ax0.set_xlabel(column)
        ax0.set_ylabel("Frequency")
        # Plotting the pie chart
        ax1.pie(dist, labels=dist.index, autopct="%1.2f%%")
        ax1.set_title(f"Pie Chart Distribution for {column}")
        return plt.show()
    else:
        print("The column given is not a Categorical Column")

# %%
plot_bar_pie("Title")

# %%
plot_bar_pie("BusinessUnit")

# %%
plot_bar_pie("EmployeeStatus")

# %%
plot_bar_pie("EmployeeType")

# %%
plot_bar_pie("DepartmentType")

# %%
plot_bar_pie("MaritalDesc")

# %%
plot_bar_pie("GenderCode")

# %%
plot_bar_pie("Performance Score")
